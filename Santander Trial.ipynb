# %%
import numpy as np
import pandas as pd

# %%
data_df_1 = pd.read_csv('aCLIENTES_OCT2012.txt', sep=';', dtype=str)
data_df_2 = pd.read_csv('aCLIENTES_OCT2012.txt', sep=';', dtype=str)
data_df_3 = pd.read_csv('aCLIENTES_OCT2012.txt', sep=';', dtype=str)

# %%
aa = set(data_df_1.AA1)
bb = set(data_df_2.AA1)
cc = set(data_df_3.AA1)
# Out:
# pandas.core.series.Series

# %%
inter = cc.intersection(aa.intersection(bb))

month = ["oct12", 'sept12']
datafiles = ["aCLIENTES_OCT2012.txt", "bCLIENTES_SEP2012.txt"]

# initialize new files per month 
# create a file and close

for each_client in inter:
    for each_month, datafile  in zip(month, datafiles):
        # activity_by_this_month, client_data_for_this_month = computeActivity(each_client, month) # returns 1 or 0
        # writeToFile(each_client, activity_by_this_month, month, client_data_for_this_month) # file must just append
        pass
# Out:
# {'05451384',
#  '02930152',
#  '05763318',
#  '60291015',
#  '60157715',
#  '02513675',
#  '05451386',
#  '01319503',
#  '00136621',
#  '00136627',
#  '60352386',
#  '30227127',
#  '30227126',
#  '30227125',
#  '30227124',
#  '30227122',
#  '04282896',
#  '04282895',
#  '04282894',
#  '04282893',
#  '04500478',
#  '04282891',
#  '20275260',
#  '05695097',
#  '05695094',
#  '05695095',
#  '50250710',
#  '50250711',
#  '05695090',
#  '50250713',
#  '02894266',
#  '70197561',
#  '70197560',
#  '02894268',
#  '30128851',
#  '03655877',
#  '03655874',
#  '30128850',
#  '01200279',
#  '04123648',
#  '02935653',
#  '60343745',
#  '04123645',
#  '30420731',
#  '30420730',
#  '30420733',
#  '30420735',
#  '30420734',
#  '70090684',
#  '70090685',
#  '30420739',
#  '70404804',
#  '70090689',
#  '70404801',
#  '70404800',
#  '70404803',
#  '70404802',
#  '04819669',
#  '04819667',
#  '02626543',
#  '03339811',
#  '02626547',
#  '03339812',
#  '02246165',
#  '80107801',
#  '80107807',
# ...

# %%
# Out:
# {'05451384',
#  '02930152',
#  '05763318',
#  '60291015',
#  '60157715',
#  '02513675',
#  '05451386',
#  '01319503',
#  '00136621',
#  '00136627',
#  '60352386',
#  '30227127',
#  '30227126',
#  '30227125',
#  '30227124',
#  '30227122',
#  '04282896',
#  '04282895',
#  '04282894',
#  '04282893',
#  '04500478',
#  '04282891',
#  '20275260',
#  '05695097',
#  '05695094',
#  '05695095',
#  '50250710',
#  '50250711',
#  '05695090',
#  '50250713',
#  '02894266',
#  '70197561',
#  '70197560',
#  '02894268',
#  '30128851',
#  '03655877',
#  '03655874',
#  '30128850',
#  '01200279',
#  '04123648',
#  '02935653',
#  '60343745',
#  '04123645',
#  '30420731',
#  '30420730',
#  '30420733',
#  '30420735',
#  '30420734',
#  '70090684',
#  '70090685',
#  '30420739',
#  '70404804',
#  '70090689',
#  '70404801',
#  '70404800',
#  '70404803',
#  '70404802',
#  '04819669',
#  '04819667',
#  '02626543',
#  '03339811',
#  '02626547',
#  '03339812',
#  '02246165',
#  '80107801',
#  '80107807',
# ...

# %%
rows, cols = data_df.shape
new_header = ['A'+str(i) for i in range(0,cols)]

data_df = pd.read_csv('aCLIENTES_OCT2012.txt', sep=';')
a = data_df.AA4 + data_df.AA2

# %%
data_df.AA1
# Out:
# 0     000000A1
# 1     00000020
# 2     02758032
# 3     00000045
# 4     02743263
# 5     00000073
# 6     02715869
# 7     00000096
# 8     00000098
# 9     00000099
# 10    00000102
# 11    00000122
# 12    00000142
# 13    00000161
# 14    00000171
# ...
# 2288422    10452621
# 2288423    30453398
# 2288424    70451838
# 2288425    30455784
# 2288426    40452618
# 2288427     6182946
# 2288428    30454597
# 2288429    20451937
# 2288430    50454609
# 2288431    80454579
# 2288432    20451411
# 2288433    20452346
# 2288434    40451670
# 2288435    20451255
# 2288436    70451382
# Name: AA1, Length: 2288437, dtype: object

# %%
m = m.tolist()

# %%
mm = '000000A1' in m
mm
# Out:
# True
